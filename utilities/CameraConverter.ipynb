# %%
import gym
from gym import spaces
import numpy as np

# %%
#https://stackoverflow.com/questions/7085512/check-what-number-a-string-ends-with-in-python
import re
def get_trailing_number(s):
    m = re.search(r'\d+$', s)
    return int(m.group()) if m else None

# %%
class CameraConverter:
    def __init__(self):
        self.box_space = spaces.Box(low=-180.0, high=180.0, shape=(2,))
        self.discrete_space = spaces.Dict({
            'changepitch_0': spaces.Discrete(2),
            'changepitch_-10': spaces.Discrete(2),
            'changepitch_-20': spaces.Discrete(2),
            'changepitch_-30': spaces.Discrete(2),
            'changepitch_-40': spaces.Discrete(2),
            'changepitch_-50': spaces.Discrete(2),
            'changepitch_-60': spaces.Discrete(2),
            'changepitch_-70': spaces.Discrete(2),
            'changepitch_-80': spaces.Discrete(2),
            'changepitch_-90': spaces.Discrete(2),
            'changepitch_-100': spaces.Discrete(2),
            'changepitch_-110': spaces.Discrete(2),
            'changepitch_-120': spaces.Discrete(2),
            'changepitch_-130': spaces.Discrete(2),
            'changepitch_-140': spaces.Discrete(2),
            'changepitch_-150': spaces.Discrete(2),
            'changepitch_-160': spaces.Discrete(2),
            'changepitch_-170': spaces.Discrete(2),
            'changepitch_-180': spaces.Discrete(2),
            'changepitch_10': spaces.Discrete(2),
            'changepitch_20': spaces.Discrete(2),
            'changepitch_30': spaces.Discrete(2),
            'changepitch_40': spaces.Discrete(2),
            'changepitch_50': spaces.Discrete(2),
            'changepitch_60': spaces.Discrete(2),
            'changepitch_70': spaces.Discrete(2),
            'changepitch_80': spaces.Discrete(2),
            'changepitch_90': spaces.Discrete(2),
            'changepitch_100': spaces.Discrete(2),
            'changepitch_110': spaces.Discrete(2),
            'changepitch_120': spaces.Discrete(2),
            'changepitch_130': spaces.Discrete(2),
            'changepitch_140': spaces.Discrete(2),
            'changepitch_150': spaces.Discrete(2),
            'changepitch_160': spaces.Discrete(2),
            'changepitch_170': spaces.Discrete(2),
            'changepitch_180': spaces.Discrete(2),
            'changeyaw_0': spaces.Discrete(2),
            'changeyaw_-10': spaces.Discrete(2),
            'changeyaw_-20': spaces.Discrete(2),
            'changeyaw_-30': spaces.Discrete(2),
            'changeyaw_-40': spaces.Discrete(2),
            'changeyaw_-50': spaces.Discrete(2),
            'changeyaw_-60': spaces.Discrete(2),
            'changeyaw_-70': spaces.Discrete(2),
            'changeyaw_-80': spaces.Discrete(2),
            'changeyaw_-90': spaces.Discrete(2),
            'changeyaw_-100': spaces.Discrete(2),
            'changeyaw_-110': spaces.Discrete(2),
            'changeyaw_-120': spaces.Discrete(2),
            'changeyaw_-130': spaces.Discrete(2),
            'changeyaw_-140': spaces.Discrete(2),
            'changeyaw_-150': spaces.Discrete(2),
            'changeyaw_-160': spaces.Discrete(2),
            'changeyaw_-170': spaces.Discrete(2),
            'changeyaw_-180': spaces.Discrete(2),
            'changeyaw_10': spaces.Discrete(2),
            'changeyaw_20': spaces.Discrete(2),
            'changeyaw_30': spaces.Discrete(2),
            'changeyaw_40': spaces.Discrete(2),
            'changeyaw_50': spaces.Discrete(2),
            'changeyaw_60': spaces.Discrete(2),
            'changeyaw_70': spaces.Discrete(2),
            'changeyaw_80': spaces.Discrete(2),
            'changeyaw_90': spaces.Discrete(2),
            'changeyaw_100': spaces.Discrete(2),
            'changeyaw_110': spaces.Discrete(2),
            'changeyaw_120': spaces.Discrete(2),
            'changeyaw_130': spaces.Discrete(2),
            'changeyaw_140': spaces.Discrete(2),
            'changeyaw_150': spaces.Discrete(2),
            'changeyaw_160': spaces.Discrete(2),
            'changeyaw_170': spaces.Discrete(2),
            'changeyaw_180': spaces.Discrete(2)
        })
        
        
    
    def box_to_discrete(self, box_sample):
        import math
        
        pitch = round(box_sample[0],-1)
        yaw = round(box_sample[1],-1)
        
        ret_dict = {
            'changepitch_0': 0,
            'changepitch_-10': 0,
            'changepitch_-20': 0,
            'changepitch_-30': 0,
            'changepitch_-40': 0,
            'changepitch_-50': 0,
            'changepitch_-60': 0,
            'changepitch_-70': 0,
            'changepitch_-80': 0,
            'changepitch_-90': 0,
            'changepitch_-100': 0,
            'changepitch_-110': 0,
            'changepitch_-120': 0,
            'changepitch_-130': 0,
            'changepitch_-140': 0,
            'changepitch_-150': 0,
            'changepitch_-160': 0,
            'changepitch_-170': 0,
            'changepitch_-180': 0,
            'changepitch_10': 0,
            'changepitch_20': 0,
            'changepitch_30': 0,
            'changepitch_40': 0,
            'changepitch_50': 0,
            'changepitch_60': 0,
            'changepitch_70': 0,
            'changepitch_80': 0,
            'changepitch_90': 0,
            'changepitch_100': 0,
            'changepitch_110': 0,
            'changepitch_120': 0,
            'changepitch_130': 0,
            'changepitch_140': 0,
            'changepitch_150': 0,
            'changepitch_160': 0,
            'changepitch_170': 0,
            'changepitch_180': 0,
            'changeyaw_0': 0,
            'changeyaw_-10': 0,
            'changeyaw_-20': 0,
            'changeyaw_-30': 0,
            'changeyaw_-40': 0,
            'changeyaw_-50': 0,
            'changeyaw_-60': 0,
            'changeyaw_-70': 0,
            'changeyaw_-80': 0,
            'changeyaw_-90': 0,
            'changeyaw_-100': 0,
            'changeyaw_-110': 0,
            'changeyaw_-120': 0,
            'changeyaw_-130': 0,
            'changeyaw_-140': 0,
            'changeyaw_-150': 0,
            'changeyaw_-160': 0,
            'changeyaw_-170': 0,
            'changeyaw_-180': 0,
            'changeyaw_10': 0,
            'changeyaw_20': 0,
            'changeyaw_30': 0,
            'changeyaw_40': 0,
            'changeyaw_50': 0,
            'changeyaw_60': 0,
            'changeyaw_70': 0,
            'changeyaw_80': 0,
            'changeyaw_90': 0,
            'changeyaw_100': 0,
            'changeyaw_110': 0,
            'changeyaw_120': 0,
            'changeyaw_130': 0,
            'changeyaw_140': 0,
            'changeyaw_150': 0,
            'changeyaw_160': 0,
            'changeyaw_170': 0,
            'changeyaw_180': 0
        }
        ret_dict['changepitch_'+str(pitch)] = 1
        ret_dict['changeyaw_'+str(yaw)] = 1
        
        assert(self.discrete_space.contains(ret_dict))
        
        return ret_dict
    
    def discrete_to_box(self, discrete_sample):
        
        pitch = 0
        yaw = 0
        #print(discrete_sample)
        for name,value in discrete_sample.items():
            if (value):
                if ("pitch" in name):
                    pitch = get_trailing_number(name)
                if ("yaw" in name):
                    yaw = get_trailing_number(name)
        
        """
        if(discrete_sample['look_up'] == 1):
            pitch = self.delta_degrees
        elif(discrete_sample['look_down']):
            pitch = -self.delta_degrees
        else:
            pitch = 0
            
        if(discrete_sample['look_right'] == 1):
            yaw = self.delta_degrees
        elif(discrete_sample['look_left']):
            yaw = -self.delta_degrees
        else:
            yaw = 0
        """    
        ret_arr = np.array([pitch, yaw])    
        
        assert(self.box_space.contains(ret_arr))
        
        
        return ret_arr
